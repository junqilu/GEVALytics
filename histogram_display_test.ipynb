# %% [markdown]
# # Import packages

# %% [markdown]
# # Custom functions

# %%
from histogram_data_parameters import csv_files_in_dir
from histogram_display import display_all_histogram_as_line_plots

# %% [markdown]
# # Read in example data

# %%
file_list = csv_files_in_dir('example_input_data')
file_list
# Out:
# ['example_input_data\\example_histogram_data_0.csv',
#  'example_input_data\\example_histogram_data_1.csv',
#  'example_input_data\\example_histogram_data_2.csv']

# %% [markdown]
# # Tests

# %% [markdown]
# ## All line plots resembling histograms

# %%
display_all_histogram_as_line_plots(
    file_list,
    split_filename_components_list=['0','1','2'],
    xlim_min = 0,
    xlim_max = 14,
    ylim_min = 0,
    ylim_max = 2000,
    color_lists=['red', 'green', 'blue', 'orange','purple', 'brown', 'pink', 'gray']
)
